# %% [markdown]
# <a href="https://colab.research.google.com/github/Visserys/Visserys/blob/main/G4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Library

import pickle
import json
import pandas as pd
import numpy as np

# %%
# Load file model

with open('model_lin.pkl', 'rb') as file_1:
  model_lin = pickle.load(file_1)

with open('model_scaler.pkl', 'rb') as file_2:
  model_scaler = pickle.load(file_2)

with open('model_encoder.pkl', 'rb') as file_3:
  model_encoder = pickle.load(file_3)

with open('list_num_column.txt', 'rb') as file_4:
  list_num_column = pickle.load(file_4)

with open('list_cat_col.txt', 'rb') as file_5:
  list_cat_col = pickle.load(file_5)

# %%
# Create New Data

data_inf = {
    'hour':17,
    'day':1,
    'cab_type':'Uber',
    'name':'UberPool',
    'distance':1,
    'surge_multiplier':2.0,
    'short_summary':' Clear ',

}

# %%
# convert to dataframe
data_inf = pd.DataFrame([data_inf])
data_inf
# Out:
#    hour  day cab_type      name  distance  surge_multiplier short_summary
# 0    17    1     Uber  UberPool         1               2.0        Clear

# %%
#Split between numerical and categorical column

data_inf_num = data_inf[list_num_column]
data_inf_cat = data_inf[list_cat_col]
data_inf_num
# Out:
#    hour  day  distance  surge_multiplier
# 0    17    1         1               2.0

# %%
data_inf_cat
# Out:
#   cab_type      name short_summary
# 0     Uber  UberPool        Clear

# %%
# Scaling and Encoding

data_inf_num_scaled = model_scaler.transform(data_inf_num)
data_inf_cat_encoded = model_encoder.transform(data_inf_cat).toarray()

# Concat numerical and categorical
data_inf_final = np.concatenate([data_inf_num_scaled,data_inf_cat_encoded],axis=1)

# %%
# Predict using Linear Regression
y_pred_inf = model_lin.predict(data_inf_final)

print('price:',round(y_pred_inf[0], 2))
# Out:
# price: 18.99
